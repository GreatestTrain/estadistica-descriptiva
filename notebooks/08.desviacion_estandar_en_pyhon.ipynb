# %% [markdown]
# Medidas de disperción en _**python**_
# -
# ---

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

df = pd.read_csv('./resources/cars.csv')
df.sample(2)
# Out:
#      manufacturer_name model_name transmission  color  odometer_value  \
# 9957              Ford     Sierra   mechanical    red            1111
# 1303               Kia    Spectra   mechanical  white          209000
#
#       year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 9957           1990    gasoline           False    gasoline              2.0
# 1303           2006    gasoline           False    gasoline              1.6
#
#       ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# 9957  ...     False      False     False     False      False      False
# 1303  ...      True       True      True     False       True      False
#
#      feature_7  feature_8  feature_9  duration_listed
# 9957     False      False      False               10
# 1303     False       True       True              129
#
# [2 rows x 30 columns]

# %%
# Desviación Estándar
df['price_usd'].std()
# Out:
# 6428.1520182029035

# %%
df['price_usd'].max() - df['price_usd'].min()
# Out:
# 49999.0

# %%
df['price_usd'].median()
# Out:
# 4800.0

# %%
class Percentiles:
    def __init__(self, min=0, max=1, jumpby=0.25):
        self.jumpby = jumpby
        if min >= 0:
            self.min = min
        else:
            print("Tiene que ser mayor o igual que cero")
            raise ValueError
        if max <= 1:
            self.max = max
        else:
            print("Tiene que ser menor o igual que 1")
            raise ValueError
    def __iter__(self):
        self.counter = self.min
        return self
    def __next__(self):
        if self.counter <= self.max:
            y = self.counter
            self.counter += self.jumpby
            return round(y, 2)
        else:
            raise StopIteration

# %%
def run():
    op = int(input("""
    1. Percentiles
    2. Cuartiles
    """))
    if op == 1:
        iterator = Percentiles(jumpby=0.01)
    elif op == 2:
        iterator = Percentiles(jumpby=0.25)
    else:
        print('Inserta una opción válida')
        run()
    for i in iterator:
        print(df['price_usd'].quantile(q=i))
        
run()
# Out:
# 1.0
# 2100.0
# 4800.0
# 8990.0
# 50000.0

# %% [markdown]
# ### Límites para detección de outliers (datos simetricamente distribuidos)
#
# Datos entre $$Q_1 -1.5 \times \text{IQR}$$ y $$Q_3 + 1.5 \times \text{IQR}$$

# %%
q3 = df['price_usd'].quantile(q=0.75)
q1 = df['price_usd'].quantile(q=0.25)

iqr = q3-q1
min_limit = q1 - 1.5 * iqr
max_limit = q3 + 1.5 * iqr

print(min_limit, "\n", max_limit)
# Out:
# -8235.0
#  19325.0

# %%
sns.histplot(data = df, x = 'price_usd')
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
sns.boxplot( x = 'year_produced', y = 'price_usd', data = df)
# Out:
# <AxesSubplot:xlabel='year_produced', ylabel='price_usd'>

# %%
g = sns.FacetGrid(data = df, row ='manufacturer_name', height=3, aspect = 2)
g.map(sns.boxplot, 'year_produced', 'price_usd', 'engine_type')
# Out:
# C:\Users\Cesar\.conda\envs\data_science\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\Cesar\.conda\envs\data_science\lib\site-packages\seaborn\axisgrid.py:675: UserWarning: Using the boxplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df.count()
# Out:
# manufacturer_name    38531
# model_name           38531
# transmission         38531
# color                38531
# odometer_value       38531
# year_produced        38531
# engine_fuel          38531
# engine_has_gas       38531
# engine_type          38531
# engine_capacity      38521
# body_type            38531
# has_warranty         38531
# state                38531
# drivetrain           38531
# price_usd            38531
# is_exchangeable      38531
# location_region      38531
# number_of_photos     38531
# up_counter           38531
# feature_0            38531
# feature_1            38531
# feature_2            38531
# feature_3            38531
# feature_4            38531
# feature_5            38531
# feature_6            38531
# feature_7            38531
# feature_8            38531
# feature_9            38531
# duration_listed      38531
# dtype: int64

# %%
sns.relplot(
    data=df, y="price_usd", x='year_produced', hue='manufacturer_name',
    row="engine_type",
    kind="scatter"
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manufacturer_name  38531 non-null  object
#  1   model_name         38531 non-null  object
#  2   transmission       38531 non-null  object
#  3   color              38531 non-null  object
#  4   odometer_value     38531 non-null  int64
#  5   year_produced      38531 non-null  int64
#  6   engine_fuel        38531 non-null  object
#  7   engine_has_gas     38531 non-null  bool
#  8   engine_type        38531 non-null  object
#  9   engine_capacity    38521 non-null  float64
#  10  body_type          38531 non-null  object
#  11  has_warranty       38531 non-null  bool
#  12  state              38531 non-null  object
#  13  drivetrain         38531 non-null  object
#  14  price_usd          38531 non-null  float64
#  15  is_exchangeable    38531 non-null  bool
#  16  location_region    38531 non-null  object
#  17  number_of_photos   38531 non-null  int64
#  18  up_counter         38531 non-null  int64
#  19  feature_0          38531 non-null  bool
#  20  feature_1          38531 non-null  bool
#  21  feature_2          38531 non-null  bool
#  22  feature_3          38531 non-null  bool
#  23  feature_4          38531 non-null  bool
#  24  feature_5          38531 non-null  bool
#  25  feature_6          38531 non-null  bool
#  26  feature_7          38531 non-null  bool
#  27  feature_8          38531 non-null  bool
#  28  feature_9          38531 non-null  bool
#  29  duration_listed    38531 non-null  int64
# dtypes: bool(13), float64(2), int64(5), object(10)
# memory usage: 5.5+ MB
